# %% [markdown]
# <a href="https://colab.research.google.com/github/JNorri/JNorri/blob/main/1_2_%D0%97%D0%BD%D0%B0%D0%BA%D0%BE%D0%BC%D1%81%D1%82%D0%B2%D0%BE_%D1%81_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Навигация по уроку**
#
# 1. [Знакомство с Google Colab](https://colab.research.google.com/drive/165RMZptKVyl7OKNt0jTiVAUcE76uBme0)
# 2. Знакомство с GitHub
# 3. [Нейросети как сервис. Как сделать свой сервис на предобученных моделях](https://colab.research.google.com/drive/11rJ3Qmuh9UHgWSjDr13us9tLF0dHCyLS)
# 4. [Домашняя работа](https://colab.research.google.com/drive/1FlOfXfKWhbEVlLZf9XfcQyaQKK_2-dTW)

# %% [markdown]
# ## Введение

# %% [markdown]
# Наверное, открыв блокнот, вы сильно удивились и находитесь в недоумении. Зачем мне профиль в GitHub? Как он связан с курсом? А где здесь нейронные сети?
#
# Немного терпения. Данный блокнот занимает важное место в курсе и поможет вам в трудоустройстве в будущем. Профиль в GitHub последнее время превратился в инструмент привлечения внимания работодателя.
#
# Профиль в GitHub — это обязательный атрибут современного разработчика. Благодаря GitHub можно найти работу, продемонстрировать свои навыки и опыт, поучаствовать в интересных проектах.
#
# Посмотрите на профиль одного из разработчиков Python. Его профиль довольно серьезный и строгий, но показатели в 21к подписчиков и 25 репозиториев, говорят сами за себя. Не путайте с подписчиками в социальных сетях. Разработчики серьезные люди и на кого попало не подписываются. Как вы можете видеть на скрине сам Гвидо подписан только на 3-х участников GitHub: коллегу по проекту, 14-летнего вундеркинда и гуру программирования из Индии, и очень странный профиль на GitHub, который сам себя позиционирует, как "Just a simple man, with a simple plan".

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В курсе будет 4 практические работы. Мы хотим, чтобы они вошли в ваше Портфолио, в виде 4-х репозиториев и помогли вам сильно вырасти в глазах работодателя. А этот блокнот вам расскажет, как использовать GitHub для карьерного роста.

# %% [markdown]
# ## Оформление профиля на GitHub

# %% [markdown]
# Многие начинающие специалисты не могут найти работу. Часто это связано с отсутствием опыта и им его нечем подтвердить. Если у опытного программиста спросят, чем он занимался на предыдущей работе, то он сможет об этом рассказать. Но тем, кто только начинает путь в IT, показать будет нечего.
#
# В последнем случае опыт нужно нарабатывать. Это можно сделать уже во время обучения, а также принимать участие в Open Source проектах. В них может принимать участие любой желающий разработчик. А продемонстрировать практику поможет GitHub.
#
# В этом уроке разберемся, зачем разработчику вести GitHub, как оформлять профиль и вести активность. Еще узнаем, чем заполнять репозиторий, если нет опыта и собственных проектов.

# %% [markdown]
# Чтобы показать свой опыт потенциальному работодателю, нужно оставить в резюме ссылку на свой профиль в [GitHub](https://github.com/). Когда работодатель перейдет по ней, то увидит информацию о вас.
#
# Ваш **код** — лучшее доказательство ваших знаний и навыков. Некоторые работодатели ищут сотрудников через анализ кода на гитхабе.
#
#
#
#
#
# Не забывайте, что репозитории нужно оформлять качественно — с описанием того, что за проекты и как их запустить. Это повышает привлекательность и интерес к проекту со стороны.
#
# Когда вы наберетесь опыта, GitHub станет еще полезнее. Например, вы сможете перейти на пассивный поиск работы. Когда будут спрашивать про ваш опыт, достаточно дать ссылку на профиль. В нем будет вся необходимая информация об используемых технологиях и примеры проектов.

# %% [markdown]
# ## Важные разделы профиля

# %% [markdown]
# ### Информация о вас

# %% [markdown]
# Основная информация профиля — это первое, что видят работодатели или рекрутеры. Поэтому ее важно оформить максимально презентабельно.
# В профиле должна быть релевантная и полезная информация: личные данные, активность в публичных проектах и свои проекты. Если на профиль зашел работодатель, то он сможет оценить ваш опыт и профессионализм и связаться с вами.
#
#
# **Хороший профиль должен содержать:**
#
#
# 1.   **Личная фотография.** Профиль в GitHub — это не документ, здесь не нужна "официальная" фотография как на паспорт или водительское удостоверение. Загрузите такое фото, которое будет располагать к себе. Во многих профилях в GitHub можно встретить фото с домашними питомцами.
# 2.   **Имя и фамилия.** Пишите настоящие имя и фамилию, так рекрутеры будут знать, что это действительно ваш профиль.
# 3.   **Репозитории.** Они нужны, чтобы продемонстрировать опыт работы. Это одна из самых важных составляющих профиля.
# 4.   **Компания.** Компанию, в которой вы работаете.
# 5.   **Локация.** Место вашего географического местоположения.
# 6.   **Социальные сети**. Ссылку на личный сайт и на аккаунт в соц.сети.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Профиль желательно оформлять на английском языке. Его можно назвать стандартом общения в IT, даже если вы не планируете выходить на международный рынок.
#
# Многие рекрутеры и работодатели только по основной информации о кандидате принимают решение, брать ли его на работу. Поэтому этой составляющей профиля не стоит пренебрегать.
#
# Если вы хотите написать краткую биографию и интересные факты о себе, то это можно сделать в специальном репозитории, в котором размещается текстовый файл README.md.

# %% [markdown]
# #### Как оформлять README

# %% [markdown]
# Репозиторий, в котором размещается текстовый файл, должен называться так же, как и ник (nickname) на GitHub: `https://github.com/<username>/<username>`. Например, если ваш ник StudentX, то репозиторий должен называться `https://github.com/StudentX/StudentX`.
#
# README.md оформляется с помощью языка разметки Markdown и отображается на странице профиля. Язык Markdown достаточно простой и специально его нет смысла изучать. Так как текстовые ячейки блокнотов курса написаны с использованием Markdown, то вы всегда можете двойным кликом по текстовой ячейке подсмотреть, как она оформлена.
#
#
# В этом файле может быть любая информация, которая будет полезна другим. Это можно сравнить с резюме, в котором стоит указать следующую информацию:
#
# 1.   **Образование.** Укажите наличие высшего образования. Если вы еще учитесь, то укажите его как неоконченное.
# 2.   **Дополнительное образование.** Укажите курсы, участие в хакатонах, воркшопах и других похожих мероприятиях. Можете рассказать о книгах, которые читали, рассказать о своем читательском опыте.
# 3.   **Опыт работы.** Указывайте любой опыт, который хотя бы косвенно связан с разработкой. Опыт стоит указывать через достижения — чего удалось добиться на предыдущих проектах. Также интересен опыт внедрения новых технологий, какова была ваша роль в этом внедрении.
# 4.    **О себе.** Расскажите немного о себе, чтобы найти точки соприкосновения с работодателем. Сюда можно добавить информацию, которая не вошла ни в один из блоков, но вам важно об этом сказать. Можно рассказать о том, какие языки программирования вы изучаете, за какими ресурсами следите.
# 5.    **Ключевые навыки.** Не указывайте слова, про которые вы слышали и примерно представляете, но никогда не работали с ними. Если вы пробовали разные языки, то так и напишите «написал пару скриптов на python». Четко разделяйте хорошо знакомые вам вещи, и те, с которыми вы знакомы только поверхностно. Разделяйте навыки на фундаментальные и прикладные.
#
# К фундаментальным относятся:
#
# *   Знание операционных систем
# *   Знание сетевых технологий
# *   Знание алгоритмов
# *   Уровень математической подготовки
# *   Базы знаний
#
# К прикладным:
# *   Языки программирования и уровень их владения.
# *   Фреймворки и библиотеки.
# *   Владение навыками автоматического тестирования.
#
# Указывая библиотеки и фреймворки, надо быть крайне осторожными. Если вы укажете все, что когда-либо видели, то из этого "леса" работодатель сделает неправильный вывод о вашем уровне. Работодатель прекрасно понимает, что если вы нигде не работали (либо опыт менее 3 лет), но при этом "много знаете", то грош цена этим знаниям. Указывайте только то, что может быть важно работодателям.
#
# Кроме перечисленных блоков, укажите в этом файле ссылки на другие социальные сети и статус занятости. Так работодатель сможет лучше изучить вас и поймет, свободны ли вы сейчас как специалист.

# %% [markdown]
# #### О чем не стоит писать

# %% [markdown]
# Не указывайте форматы данных, например, json или xml. Со стороны это смотрится, как: *Я знаю текстовый, числовой тип данных, числа с плавающей точкой, массивы, списки...* И при этом рассказываете про один единственный язык программирования.
#
# Не добавляйте похожие вещи, например, разные версии одних и тех же библиотек и фреймворков.
#
# Не указывайте базовые навыки по работе с компьютером, опыт работы с офисными документами. Вы нанимаетесь программистом, а не оператором ЭВМ. Профессиональное владение компьютером подразумевается уже тем, что у вас есть профиль на GitHub.

# %% [markdown]
# ### Активность в публичных проектах

# %% [markdown]
# Работодатели часто обращают внимание на активность программиста. Этот показатель отражает, насколько человек вовлечен в работу, сколько он уделяет этому времени, какие направления ему интересны, где он силен и пробует себя.
#
# Любая публичная активность на GitHub отмечается в профиле. Например, коммиты в свои или чужие репозитории, пулл-реквесты. Публичная активность отображается всем, поэтому рекрутеры, работодатели и другие разработчики видят, где вы принимали участие и что делали.
#
# Например, можно принять участие в разработке фреймворка или библиотеки. Такую активность обязательно оценят.
#
# Публичная активность — это отличный способ заявить о себе. В первую очередь рекрутеры обращают внимание на те проекты, которые вы разрабатываете сами. Они отображаются в репозитории.

# %% [markdown]
# ### Репозитории

# %% [markdown]
# Репозиторий содержит все файлы проекта и историю их изменений. Он отражает опыт разработчика. Но его нужно хорошо оформить.
#
# **Рекомендуемые пункты по оформлению репозитория:**
#
# 1.   Краткое описание проекта. Отображается на главной странице, если репозиторий прикреплен в профиле. Работодатель, который изучает ваши работы, сможет выбрать нужный ему проект и не заходить в каждый.
# 2.   README проекта. GitHub по умолчанию отображает файл README.md на странице репозитория. README.md — это краткая документация. Это первое, что видит человек, который открывает репозиторий. Поэтому здесь важно дать достаточно информации о проекте и рассказать, что он из себя представляет.
#
# > В нем можно указать следующую информацию о проекте:
# *   Команды установки, локального запуска, запуска тестов и т.д.
# *   Примеры использования (ссылка на страницу с веб-демонстрацией, примеры использования в коде или скриншоты)
# *   Информация о том, можно ли поучаствовать в этом проекте
# *   Контактная информация, контакты технической поддержки и т.д.
# *   Ответы на частые вопросы
#
# 3.   Код проекта соответствует общепринятым стандартам, используется GitHub Actions и написаны тесты
# 4.   Проект работает и выполняет свою задачу

# %% [markdown]
# Любой программист может разработать свой проект. Можно придумать свой проект, можно взять идею со стороны. Главная цель проектов начинающего разработчика — показать, что вы умеете разрабатывать.
#
# Вы как наш студент, можете упаковывать свои домашние и практические работы в проекты и публиковать на свой GitHub. Только помните, что ваша цель выделиться среди остальных соискателей, поэтому должны относиться со всей серьезности к качеству публикуемых проектов. Они не должны смотреться как домашние работы с привязкой к курсу, они должны быть цельными программами, интересными для работодателя. Публикуйте свои навыки по результатам серии домашних работ, добавляйте творческого мышления и выбирайте интересные датасеты.
#
# Также вы можете выполнять тестовые задания из различных компаний.
#
# В книгах по программированию содержатся задания к каждой главе. Создайте под книгу отдельный репозиторий и выкладывайте там код. Проводя свой собственный разбор примеров из книг, предлагая новые решения и алгоритмы, вы можете привлечь внимание других читателей книг, и организовать целые коммьюнити по этим книгам вокруг себя.
#
# По мере роста, вас как программиста, вы будете вносить изменения в профиль. Удаляйте старые простые проекты, которые уже не отражают текущий ваш опыт, и добавляйте новые.
#
# Репозитории — способ показать ваш опыт и навыки. Так вы можете доказать, что не только принимаете активное участие в публичных проектах, но и создаете свои.

# %% [markdown]
# ## Как еще прокачать навыки?

# %% [markdown]
# В среде разработчиков популярны сервисы вопросов-ответов такие, как [Stackoverflow](https://stackoverflow.com/) или [Хабр Q&A](https://qna.habr.com/help/about). Даже если вы только начинаете свой путь, всегда есть люди, которые знают меньше вас. Зарегистрируйтесь на этих сервисах и начните отслеживать вопросы от новичков. Даже десяток полезных ответов даст вам много плюсов в карму. Работодатели ценят такую активность.
#
# Также рекомендуем воспользоваться бесплатным помощником для создания красивых GitHub-профилей [ProfileMe](https://www.profileme.dev/). Это удобный редактор Markdown. В нем можно выбрать один из более 50 языков программирования и фреймворков. Еще с его помощью можно дать ссылки на профили в социальных сетях и делиться статистикой.
#
# Пока вы только учитесь, вы будете загружать свои проекты через форму на GitHub. Работодатели оценивают и навыки работы с Git, как оформляются комммиты. Мы будем говорить немного о нем, изучая среду разработки.

# %% [markdown]
# На этом знакомство с GitHub завершено и пора перейти к самим нейронным сетям. [Нейросети как сервис. Как сделать свой сервис на предобученных моделях](https://colab.research.google.com/drive/11rJ3Qmuh9UHgWSjDr13us9tLF0dHCyLS#scrollTo=Tfob4mqXwSmY)
